# %%
# import modules:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print("All modules successfully imported!")
# Out:
# All modules successfully imported!

# %%
#import covid 19 corona_dataset
corona_dataset = pd.read_csv('C:\\Users\\asus\\Desktop\\covid19.csv')
corona_dataset.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
corona_dataset.shape
# Out:
# (266, 104)

# %%
#drop useless columns
corona_dataset.drop(["Lat","Long"],axis = 1,inplace = True)
corona_dataset.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
#Aggregating the rows by the country
df = corona_dataset.groupby("Country/Region").sum()
df.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  4/21/20  \
# Country/Region                                           ...
# ...

# %%
df.shape
# Out:
# (187, 102)

# %%
#Visualizing data related to a country
df.loc["China"].plot()
df.loc["India"].plot()
df.loc["Russia"].plot()
plt.legend()

# %%
df.loc['India'][70:75].plot()

# %%
df.loc['India'].diff().plot()

# %%
df.loc['India'].diff().max()
# Out:
# 1893.0

# %%
df.loc['Russia'].diff().max()
# Out:
# 7099.0

# %%
countries = list(df.index)
max_infection = []
for corona in countries:
    max_infection.append(df.loc[corona].diff().max())
df['max_infections'] = max_infection 
df.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %%
#new columns
new_columns = pd.DataFrame(df["max_infections"])
new_columns.head()
# Out:
#                 max_infections
# Country/Region
# Afghanistan              232.0
# Albania                   34.0
# Algeria                  199.0
# Andorra                   43.0
# Angola                     5.0

# %%
happiness_dataset = pd.read_csv("C:\\Users\\asus\\Desktop\\happiness.csv")
happiness_dataset.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
#drop columns
useless = ["Overall rank",'Score','Generosity','Perceptions of corruption']
happiness_dataset.drop(useless,axis = 1,inplace = True)
happiness_dataset.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
happiness_dataset.set_index(["Country or region"],inplace = True)
happiness_dataset.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
#join datasets
data = new_columns.join(happiness_dataset).copy()
data.head()
# Out:
#                 max_infections  GDP per capita  Social support  \
# Country/Region
# Afghanistan              232.0           0.350           0.517
# Albania                   34.0           0.947           0.848
# Algeria                  199.0           1.002           1.160
# Andorra                   43.0             NaN             NaN
# Angola                     5.0             NaN             NaN
#
#                 Healthy life expectancy  Freedom to make life choices
# Country/Region
# Afghanistan                       0.361                         0.000
# Albania                           0.874                         0.383
# Algeria                           0.785                         0.086
# Andorra                             NaN                           NaN
# Angola                              NaN                           NaN

# %%
data.corr()
# Out:
#                               max_infections  GDP per capita  Social support  \
# max_infections                      1.000000        0.250118        0.191958
# GDP per capita                      0.250118        1.000000        0.759468
# Social support                      0.191958        0.759468        1.000000
# Healthy life expectancy             0.289263        0.863062        0.765286
# Freedom to make life choices        0.078196        0.394603        0.456246
#
#                               Healthy life expectancy  \
# max_infections                               0.289263
# GDP per capita                               0.863062
# Social support                               0.765286
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.427892
#
#                               Freedom to make life choices
# max_infections                                    0.078196
# ...

# %%
#visualize
data.head()
# Out:
#                 max_infections  GDP per capita  Social support  \
# Country/Region
# Afghanistan              232.0           0.350           0.517
# Albania                   34.0           0.947           0.848
# Algeria                  199.0           1.002           1.160
# Andorra                   43.0             NaN             NaN
# Angola                     5.0             NaN             NaN
#
#                 Healthy life expectancy  Freedom to make life choices
# Country/Region
# Afghanistan                       0.361                         0.000
# Albania                           0.874                         0.383
# Algeria                           0.785                         0.086
# Andorra                             NaN                           NaN
# Angola                              NaN                           NaN

# %%
#Plotting GDP vs maximum Infection rate
x = data['GDP per capita']
y = data['max_infections']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %%
#Plotting Social support vs maximum Infection rate
x = data['Social support']
y = data['max_infections']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %%
#Plotting Healthy life expectancy vs maximum Infection rate
x = data['Healthy life expectancy']
y = data['max_infections']
sns.scatterplot(x,np.log(y))

# %%
#Plotting Freedom to make life choices vs maximum Infection rate
x = data['Freedom to make life choices']
y = data['max_infections']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))
